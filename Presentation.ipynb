# %%
from IPython.display import Image
import warnings
warnings.filterwarnings("ignore")
pd.options.display.max_rows = 10

# %% [markdown]
# # What do you feel like listening to?

# %%
Image("spotify_img.jpg")

# %% [markdown]
# ## Research Question
# - ### Can we accurately determine whether a song feels happy or sad?
#
# ## Part 1: Gathering and Cleaning Data
# - Participant's song Title, Artist and Sentiment data(csv).
# - Musical and auditory attributes of songs(api/json) [Spotify Web API](https://developer.spotify.com/documentation/web-api/reference/).

# %%
import pandas as pd
import numpy as np
user_df = pd.read_csv("https://raw.githubusercontent.com/jallen182/Data301/master/songs6.csv")
user_df.head()
# Out:
#         Name                       Title           Artist Sad/Happy
# 0  Stephanie                    Distance             Cake         H
# 1  Stephanie         Let's Stay Together         Al Green         H
# 2  Stephanie     Blood on your bootheels    Caroline Rose         H
# 3  Stephanie                          FM       Steely Dan         H
# 4  Stephanie  Valley of the silver moon   Jonathon Wilson        S

# %%
spotify_df = pd.read_csv("clean_data3.csv")
spotify_df = spotify_df.drop(columns='Unnamed: 0')
spotify_df[spotify_df["Name"] == "Stephanie"]
# Out:
#           Name                               Title              Artist  \
# 0    Stephanie                            Distance                Cake
# 1    Stephanie                 Let's Stay Together            Al Green
# 2    Stephanie             Blood on your bootheels       Caroline Rose
# 3    Stephanie                                  FM          Steely Dan
# 4    Stephanie          Valley of the silver moon      Jonathon Wilson
# ..         ...                                 ...                 ...
# 358  Stephanie                 The Mystery of Love       Prefab Sprout
# 359  Stephanie                  Pretty As You Feel  Jefferson Airplane
# 360  Stephanie                                 Ayn      The Ocean Blue
# 361  Stephanie  Put Your Money Where Your Mouth Is          Rose Royce
# 362  Stephanie   I Thank You - LP / Single Version          Sam & Dave
#
#     Sad/Happy                  parent  \
# 0           H                     NaN
# 1           H                     NaN
# 2           H                     NaN
# 3           H                     NaN
# 4           S                     NaN
# ..        ...                     ...
# 358         S  5vmRQ3zELMLUQPo2FLQ76x
# 359         S  4OMu5a8sFpcRCPCcsoEaov
# 360         H  10zlwR7kvVbD9OBkeZWr3L
# 361         H  262qk9k0LTyMXmjH9YT2xU
# 362         H  62r1CS9zL1FL5Ilb7hLX7n
#
#                                                  album  \
# 0    {'album_type': 'album', 'artists': [{'external...
# 1    {'album_type': 'album', 'artists': [{'external...
# 2    {'album_type': 'album', 'artists': [{'external...
# 3    {'album_type': 'compilation', 'artists': [{'ex...
# 4    {'album_type': 'album', 'artists': [{'external...
# ..                                                 ...
# 358  {'album_type': 'ALBUM', 'artists': [{'external...
# 359  {'album_type': 'ALBUM', 'artists': [{'external...
# 360  {'album_type': 'ALBUM', 'artists': [{'external...
# 361  {'album_type': 'ALBUM', 'artists': [{'external...
# 362  {'album_type': 'ALBUM', 'artists': [{'external...
#
#                                                artists  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 358  [{'external_urls': {'spotify': 'https://open.s...
# 359  [{'external_urls': {'spotify': 'https://open.s...
# 360  [{'external_urls': {'spotify': 'https://open.s...
# 361  [{'external_urls': {'spotify': 'https://open.s...
# 362  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  disc_number  \
# 0    ['AD', 'AE', 'AR', 'BE', 'BG', 'BH', 'BO', 'BR...            1
# 1    ['AD', 'AE', 'AR', 'AT', 'BE', 'BG', 'BH', 'BO...            1
# 2    ['AD', 'AT', 'BE', 'BG', 'CA', 'CH', 'CY', 'CZ...            1
# 3                                   ['CA', 'MX', 'US']            1
# 4                                   ['CA', 'MX', 'US']            1
# ..                                                 ...          ...
# 358  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...            1
# 359  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...            1
# 360  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...            1
# 361  ['AT', 'AU', 'CA', 'DE', 'DK', 'FI', 'GB', 'IE...            1
# 362  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...            1
#
#      duration_ms       ...        mode speechiness acousticness  \
# 0         179653       ...           0      0.0891      0.00796
# 1         199396       ...           0      0.0522      0.57000
# 2         195320       ...           1      0.1250      0.14400
# 3         290160       ...           0      0.0295      0.13500
# 4         632293       ...           1      0.0302      0.54300
# ..           ...       ...         ...         ...          ...
# 358       277693       ...           1      0.0242      0.22100
# 359       269587       ...           1      0.0429      0.75500
# 360       214627       ...           1      0.0303      0.00501
# 361       205160       ...           0      0.0585      0.21600
# 362       172760       ...           1      0.0922      0.31700
#
#     instrumentalness liveness  valence    tempo  \
# 0           0.002190   0.0558    0.888  183.048
# 1           0.011500   0.0542    0.507  101.985
# 2           0.000000   0.0932    0.860  160.176
# 3           0.001940   0.0946    0.717  109.383
# 4           0.789000   0.0834    0.134  107.834
# ..               ...      ...      ...      ...
# 358         0.007840   0.0782    0.337  105.028
# 359         0.001630   0.1080    0.490  106.788
# 360         0.003270   0.1060    0.826   93.387
# 361         0.007290   0.0893    0.887  111.646
# 362         0.000098   0.0711    0.711  117.920
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0xMEF2WiqKWT...
# 1    https://api.spotify.com/v1/tracks/63xdwScd1Ai1...
# 2    https://api.spotify.com/v1/tracks/5qfPr1jisW3b...
# 3    https://api.spotify.com/v1/tracks/0zw5bUUdOxVL...
# 4    https://api.spotify.com/v1/tracks/30pUYzSBJ2tB...
# ..                                                 ...
# 358  https://api.spotify.com/v1/tracks/5trtD6jDEqHK...
# 359  https://api.spotify.com/v1/tracks/7Caz24hQ36za...
# 360  https://api.spotify.com/v1/tracks/0dH3H43FLiIU...
# 361  https://api.spotify.com/v1/tracks/6RhdsaIgl7bC...
# 362  https://api.spotify.com/v1/tracks/68cD6DL9ykbs...
#
#                                           analysis_url  time_signature
# 0    https://api.spotify.com/v1/audio-analysis/0xME...               4
# 1    https://api.spotify.com/v1/audio-analysis/63xd...               4
# 2    https://api.spotify.com/v1/audio-analysis/5qfP...               4
# 3    https://api.spotify.com/v1/audio-analysis/0zw5...               4
# 4    https://api.spotify.com/v1/audio-analysis/30pU...               4
# ..                                                 ...             ...
# 358  https://api.spotify.com/v1/audio-analysis/5trt...               4
# 359  https://api.spotify.com/v1/audio-analysis/7Caz...               4
# 360  https://api.spotify.com/v1/audio-analysis/0dH3...               4
# 361  https://api.spotify.com/v1/audio-analysis/6Rhd...               4
# 362  https://api.spotify.com/v1/audio-analysis/68cD...               4
#
# [33 rows x 36 columns]

# %% [markdown]
# ## Part 2: Data Exploration

# %%
Image("fig1.png", unconfined=True)

# %% [markdown]
# ## What features determine a songs emotional sentiment?

# %%
Image("fig2.png")

# %% [markdown]
# ## What do these features mean?

# %% [markdown]
# **Valence:** “A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with **high** valence sound more **positive** (e.g. happy, cheerful, euphoric), while tracks with **low** valence sound more **negative** (e.g. sad, depressed, angry).”

# %%
Image("fig10.png")

# %% [markdown]
# **Energy** is a measure from 0.0 to 1.0 and represents a perceptual measure of *intensity* and *activity*. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has *high* energy, while a Bach prelude scores *low* on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.

# %%
Image("fig11.png")

# %% [markdown]
# ### Other important features

# %% [markdown]
# **Danceability** describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.

# %% [markdown]
# **Speechiness** detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.

# %% [markdown]
# ### Let's take another look at those graphs with these features in mind...

# %% [markdown]
# ### User Specific Data
#
# This is for all of the songs in our data set. What happens if we just look at a specific user? Will the graphs be different? For example, let's consider songs only submitted by Valen and Emily.

# %%
Image("fig9.png", unconfined=True)

# %% [markdown]
# ## Part 3: Machine Learning

# %% [markdown]
# ### What features determine a songs emotional sentiment?
# - Valence
# - Energy
# - Loudness
# - Danceability

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
features = ["danceability", "valence", "energy", "loudness"]

# %%
trainingData = spotify_df
train, test = train_test_split(trainingData, test_size=0.10)
print("Training size: {}, Test size: {}".format(len(train), len(test)))
# Out:
# Training size: 621, Test size: 69

# %%
x_train = train[features]
y_train = train["Sad/Happy"]
x_test = test[features]
y_test = test["Sad/Happy"]

# %% [markdown]
# ### Model Parameters: ###
# - **learning rate**: shrinks the contribution of each tree by learning_rate. There is a trade-off between learning_rate and n_estimators.
# - **n_estimators**: The number of boosting stages to perform. Gradient boosting is fairly robust to over-fitting so a large number usually results in better performance.

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=15, learning_rate=0.27, max_depth=1, random_state=0)
gbc.fit(x_train, y_train)
predicted = gbc.predict(x_test)
score = accuracy_score(y_test, predicted)*100
print("Accuracy using Gbc: ", round(score, 1), "%")
# Out:
# Accuracy using Gbc:  76.8 %

# %% [markdown]
# **GradientBoosting:** builds an additive model in a forward stage-wise fashion; it allows for the optimization of arbitrary differentiable loss functions. In each stage n_classes_ regression trees are fit on the negative gradient of the binomial or multinomial deviance loss function. Binary classification is a special case where only a single regression tree is induced.

# %% [markdown]
# ## Generating our own playlist!

# %%
test_df = pd.read_csv("test_data.csv")
test_df = test_df.drop(columns='Unnamed: 0')
test_df.head()
# Out:
#      Name                        Title                  Artist  Sad/Happy  \
# 0  Jeremy                Human Sadness               The Voidz        NaN
# 1  Jeremy                Trailer Trash            Modest Mouse        NaN
# 2  Jeremy                       Heroes             David Bowie        NaN
# 3  Jeremy  I’m so lonesome I could cry           Hank Williams        NaN
# 4  Jeremy               Pale Blue Eyes  The Velvet Underground        NaN
#
#   parent                                              album  \
# 0    NaN  {'album_type': 'album', 'artists': [{'external...
# 1    NaN  {'album_type': 'album', 'artists': [{'external...
# 2    NaN  {'album_type': 'album', 'artists': [{'external...
# 3    NaN  {'album_type': 'album', 'artists': [{'external...
# 4    NaN  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...            1
# 1  ['AD', 'AE', 'AR', 'AT', 'BE', 'BG', 'BH', 'BO...            1
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...            1
# 3                                 ['CA', 'MX', 'US']            1
# 4                                 ['CA', 'MX', 'US']            1
#
#    duration_ms       ...        mode speechiness acousticness  \
# 0       656836       ...           1      0.0469     0.220000
# 1       349600       ...           1      0.0347     0.076400
# 2       371413       ...           1      0.0297     0.000671
# 3       169067       ...           1      0.0304     0.812000
# 4       339533       ...           1      0.0370     0.913000
#
#   instrumentalness liveness  valence    tempo  \
# 0          0.80800   0.1130    0.132  121.623
# 1          0.00522   0.0618    0.714  163.619
# 2          0.48400   0.0920    0.435  112.114
# 3          0.00236   0.3440    0.369  112.033
# 4          0.00123   0.1030    0.310   82.641
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2avCzL6HtaJ5...
# 1  https://api.spotify.com/v1/tracks/0WkhmPY4bLSi...
# 2  https://api.spotify.com/v1/tracks/7Jh1bpe76CNT...
# 3  https://api.spotify.com/v1/tracks/4tj7IsJrn4Mv...
# 4  https://api.spotify.com/v1/tracks/7urDSX97YCwD...
#
#                                         analysis_url  time_signature
# 0  https://api.spotify.com/v1/audio-analysis/2avC...               4
# 1  https://api.spotify.com/v1/audio-analysis/0Wkh...               4
# 2  https://api.spotify.com/v1/audio-analysis/7Jh1...               4
# 3  https://api.spotify.com/v1/audio-analysis/4tj7...               3
# 4  https://api.spotify.com/v1/audio-analysis/7urD...               4
#
# [5 rows x 36 columns]

# %%
pred = gbc.predict(test_df[features])
i = 0
for prediction in pred:
    print("Title:  {}\nArtist: {}\nEmotional Sentiment: {}\n".format(test_df["Title"][i],test_df["Artist"][i], prediction))
    i+=1
# Out:
# Title:  Human Sadness
# Artist: The Voidz
# Emotional Sentiment: S
#
# Title:  Trailer Trash
# Artist: Modest Mouse
# Emotional Sentiment: H
#
# Title:  Heroes
# Artist: David Bowie
# Emotional Sentiment: H
#
# Title:  I’m so lonesome I could cry
# Artist: Hank Williams
# Emotional Sentiment: S
#
# Title:  Pale Blue Eyes
# Artist: The Velvet Underground
# Emotional Sentiment: S
#
# Title:  Folsom Prison Blues
# Artist: Johnny Cash
# Emotional Sentiment: H
#
# Title:  Fell in Love with a girl
# Artist: The White Stripes
# Emotional Sentiment: H
#
# Title:  Girlfriend
# Artist: Ty Segall
# Emotional Sentiment: H
#
# Title:  Nerve Jamming
# Artist: Bass Drum Of Death
# Emotional Sentiment: S
#
# Title:  Some Things Last a long time
# Artist: Daniel Johnston
# Emotional Sentiment: S
#
# Title:  One
# Artist: Harry Nilsson
# Emotional Sentiment: S
#
# Title:  Get Found
# Artist: Bass Drum of Death
# Emotional Sentiment: S
#
# Title:  Zond
# Artist: Pond
# Emotional Sentiment: H
#
# Title:  Ladies Of Cambridge
# Artist: Vampire Weekend
# Emotional Sentiment: H
#
# Title:  Near Wild Heaven
# Artist: R.E.M.
# Emotional Sentiment: H
#
# Title:  You Turn Me On
# Artist: George Morgan
# Emotional Sentiment: S
#
# Title:  No Man's Land
# Artist: Syd Barrett
# Emotional Sentiment: S
#
# Title:  Stroker's Theme
# Artist: The Charlie Daniels Band
# Emotional Sentiment: S
#
# Title:  Chemical Warfare
# Artist: Dead Kennedys
# Emotional Sentiment: H
#
# Title:  Fall In
# Artist: Cloud Nothings
# Emotional Sentiment: H
#
# Title:  Acid Rain
# Artist: The Spits
# Emotional Sentiment: H
#
# Title:  Flaming Home
# Artist: Mount Eerie
# Emotional Sentiment: S
#
# Title:  Morpha Too
# Artist: Big Star
# Emotional Sentiment: S
#
# Title:  Orpheus Under the Influence
# Artist: The Buttertones
# Emotional Sentiment: H

# %% [markdown]
# ## How could we improve the model?
# - ### Lyrics
# - ### User-specific models
# - ### Include different emotions

# %% [markdown]
# # Q&A
